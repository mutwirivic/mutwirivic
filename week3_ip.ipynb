# %% [markdown]
# <a href="https://colab.research.google.com/github/mutwirivic/week3_ip/blob/master/week3_ip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing required libraries
import pandas as pd
import numpy as np

# %%
#Loading the required datasets
#cells geo dataset
cells_geo_df = pd.read_csv('cells_geo.csv', delimiter=';',index_col=0)
cells_geo_df
# Out:
#         VILLES      STATUS LOCALISATION  ...          AREA     CELL_ID   SITE_CODE
# 0       ADJAME  In Service      ABIDJAN  ...           NaN  fbb2e75af3  0bb492ef17
# 1       ADJAME  In Service      ABIDJAN  ...           NaN  1502501d78  0bb492ef17
# 2       ADJAME  In Service      ABIDJAN  ...           NaN  0c2e182a0c  0bb492ef17
# 3      ASSINIE  In Service    INTERIEUR  ...           NaN  69bdfc69fd  8a1e6ce31f
# 4      ASSINIE  In Service    INTERIEUR  ...           NaN  7a1029d2ab  8a1e6ce31f
# ...        ...         ...          ...  ...           ...         ...         ...
# 3969  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  1cfc2d7ab1  f91ed8d2e9
# 3970  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  3ae1708153  f91ed8d2e9
# 3971  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  cb71f8a29c  61bee9c70c
# 3972  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  d4a6a0b645  61bee9c70c
# 3973  ZUENOULA  In Service    INTERIEUR  ...  CENTRE NORTH  f9f3e42589  61bee9c70c
#
# [3974 rows x 11 columns]

# %%
#Cells geo decription
cells_geo_description_df = pd.read_excel('cells_geo_description.xlsx',sheet_name = 0)
cells_geo_description_df
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
#CDR description
cdr_df = pd.read_excel('CDR_description.xlsx', sheet_name= 0)
cdr_df.head()
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String

# %%
#Telcom 1
t1_df = pd.read_csv('Telcom_dataset.csv')
t1_df.columns = ['PRODUCT','VALUE','DATETIME','CELL_ON_SITE','DW_A_NUMBER_INT','DW_B_NUMBER_INT','COUNTRY_A','COUNTRY_B','CELL_ID','SITE_ID']
t1_df.head()
# Out:
#   PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
#Telcom2
t2_df = pd.read_csv('Telcom_dataset2.csv')
t2_df.columns = ['PRODUCT','VALUE','DATETIME','CELL_ON_SITE','DW_A_NUMBER_INT','DW_B_NUMBER_INT','COUNTRY_A','COUNTRY_B','CELL_ID','SITE_ID']
t2_df.head()
# Out:
#   PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0     sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1   Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2     sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3   Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4     sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
#
# [5 rows x 10 columns]

# %%
#Telcom3
t3_df = pd.read_csv('Telcom_dataset3.csv')
t3_df.columns = ['PRODUCT','VALUE','DATETIME','CELL_ON_SITE','DW_A_NUMBER_INT','DW_B_NUMBER_INT','COUNTRY_A','COUNTRY_B','CELL_ID','SITE_ID']
t3_df.head()
# Out:
#   PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
#
# [5 rows x 10 columns]

# %%
#Merge all telcom dataframes into one dataframe
telcom_df = pd.concat([t1_df,t2_df,t3_df])
telcom_df
# Out:
#      PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0      Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1        sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2        sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3      Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4      Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
# ...      ...    ...                    ...  ...       ...         ...         ...
# 4996   Voice      0  2012-05-09 00:01:43.0  ...     19e2e  2aa04dcab7  f7d63a29e5
# 4997   Voice     62  2012-05-09 00:01:43.0  ...     19e2e  7f1f2f889f  b4ddb9e93c
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4999   Voice     30  2012-05-09 00:01:43.0  ...     19e2e  98ed726da2  b4130b54ab
# 5000   Voice     60  2012-05-09 00:01:43.0  ...     19e2e  1c11a2fcbb  6d70dae094
#
# [15003 rows x 10 columns]

# %%
#Exploration
#Random site code
cells_geo_df[cells_geo_df['SITE_CODE']=='0bb492ef17']
# Out:
#    VILLES      STATUS LOCALISATION  ... AREA     CELL_ID   SITE_CODE
# 0  ADJAME  In Service      ABIDJAN  ...  NaN  fbb2e75af3  0bb492ef17
# 1  ADJAME  In Service      ABIDJAN  ...  NaN  1502501d78  0bb492ef17
# 2  ADJAME  In Service      ABIDJAN  ...  NaN  0c2e182a0c  0bb492ef17
#
# [3 rows x 11 columns]

# %%
#Exploration
#random cell id
cells_geo_df[cells_geo_df['CELL_ID']=='6750e0fb7b']
# Out:
#           VILLES STATUS LOCALISATION  ...           AREA     CELL_ID   SITE_CODE
# 164   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 183   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 184   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 185   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 243   BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 244   BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 245   BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 573   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 574   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 575   BONGOUANOU    NaN    INTERIEUR  ...  ABIDJAN SOUTH  6750e0fb7b  20387d4292
# 727   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 890   BONGOUANOU    NaN    INTERIEUR  ...           EAST  6750e0fb7b  20387d4292
# 1206  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 1207  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 1208  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 1209  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 1210  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 1211  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 2203  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 2204  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 2205  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 2270  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2271  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2272  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2273  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2274  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2275  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2695  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2696  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2697  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2698  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2775  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2776  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 2777  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 3124  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 3125  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 3126  BONGOUANOU    NaN    INTERIEUR  ...     NORTH WEST  6750e0fb7b  20387d4292
# 3684  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
# 3685  BONGOUANOU    NaN      ABIDJAN  ...  ABIDJAN NORTH  6750e0fb7b  20387d4292
#
# [39 rows x 11 columns]

# %%
#Exploration
#random cell search on telcom collected from the cells geo dataframe
telcom_df[telcom_df['CELL_ID'] == 'a4731e780e']
# Out:
#      PRODUCT  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 3154   Voice      0  2012-05-07 00:01:04.0  ...     19e2e  a4731e780e  d68260ef50
# 3204     sms      0  2012-05-07 00:01:06.0  ...     19e2e  a4731e780e  d68260ef50
# 3462   Voice     62  2012-05-07 00:01:12.0  ...     19e2e  a4731e780e  d68260ef50
# 2228     sms     50  2012-05-08 00:00:36.0  ...     19e2e  a4731e780e  d68260ef50
# 4964   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
# 4998   Voice     32  2012-05-09 00:01:43.0  ...     19e2e  a4731e780e  d68260ef50
#
# [6 rows x 10 columns]

# %%
#Exploration
#Check for duplicates in cells_geo database on the CELL_ID column
cells_geo_df[cells_geo_df.duplicated()]
# Out:
#             VILLES      STATUS  ...     CELL_ID   SITE_CODE
# 184     BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 185     BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 244     BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 245     BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 574     BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 575     BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 693     PORT-BOUET  In Service  ...  bac868328a  4d3501719c
# 694     PORT-BOUET  In Service  ...  7838208973  4d3501719c
# 695     PORT-BOUET  In Service  ...  2ad65c76a7  4d3501719c
# 696     PORT-BOUET  In Service  ...  ef7586d8b9  4d3501719c
# 763        MARCORY  In Service  ...  c76d9f0541  85a1fff77f
# 933         COCODY  In Service  ...  78513e000d  a64fc672f1
# 1207    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 1208    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 1209    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 1210    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 1211    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 1554  GRAND-BASSAM  In Service  ...  f6eaeff103  ed9b516816
# 1555  GRAND-BASSAM  In Service  ...  90b8899be5  ed9b516816
# 2085       KORHOGO  In Service  ...  5f664a17ae  bdeafe55f0
# 2204    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2205    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2271    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2272    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2273    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2274    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2275    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2328           MAN  In Service  ...  43ee48e4d6  928a59b635
# 2329           MAN  In Service  ...  43ee48e4d6  928a59b635
# 2332           MAN  In Service  ...  43ee48e4d6  928a59b635
# 2469      YOPOUGON  In Service  ...  0a834b2696  c57de6fa4a
# 2696    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2697    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2698    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2776    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 2777    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 3125    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 3126    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 3502      YOPOUGON  In Service  ...  086db1b3c3  c15166ba4d
# 3503      YOPOUGON  In Service  ...  bab25957e2  c15166ba4d
# 3685    BONGOUANOU         NaN  ...  6750e0fb7b  20387d4292
# 3698        ADJAME  In Service  ...  26a72e2271  5c565fbfb1
# 3699        ADJAME  In Service  ...  fcf8faec3b  5c565fbfb1
#
# [43 rows x 11 columns]

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#           VILLES  VILLES_COUNT
# 0         COCODY           354
# 1       YOPOUGON           295
# 2          ABOBO           255
# 3        MARCORY           141
# 4    TREICHVILLE           132
# 5         ADJAME           110
# 6   YAMOUSSOUKRO           104
# 7        PLATEAU           103
# 8       KOUMASSI            91
# 9         BOUAKE            65
# 10    PORT-BOUET            61
# 11         DALOA            59
# 12     SAN-PEDRO            55
# 13        GAGNOA            55
# 14     ATTECOUBE            46
# 15    BONGOUANOU            42
# 16          DIVO            39
# 17       KORHOGO            36
# 18   BINGERVILLE            30
# 19        SOUBRE            28
